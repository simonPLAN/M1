# %% [raw]
# TP1_Classifieur Bayésien PLANCHENAULT Simon

# %% [raw]
# Importation des valeures
#
# np.where
# np.mean
# np.var
# np.unique
# pandas.DataFrame
# df.
#
#
# moyenne / variance avec 2 caracteristique

# %%
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

import scipy as sp
iris = datasets.load_iris()
Ciris = np.c_[iris.data.reshape(len(iris.data), -1), iris.target.reshape(len(iris.target), -1)]
np.random.seed(0)
np.random.shuffle(Ciris)
shuffledIrisData = Ciris[ :, :iris.data.size//len(iris.data)].reshape(iris.data.shape)
shuffledIrisTarget = Ciris[ :, iris.data.size//len(iris.data) :].reshape(iris.target.shape)

#print (iris.data)
#print (iris.target)

nbDonneeApr=100
DonneeApr=Ciris[0:nbDonneeApr]
#print(DonneeApr)


nbDonneeDev=130
DonneeDev=Ciris[nbDonneeApr:nbDonneeDev]
#print(DonneeDev)


nbDonneeTest=150
DonneeTest=Ciris[nbDonneeDev:nbDonneeTest]
#print(DonneeTest)

# %% [raw]
# Phase d'apprentissage

# %%
#on recupere la premiere colonne

LaPetale=DonneeApr[:,0]
#print(LoPetale)
LoPetale=DonneeApr[:,1]
#print(LaPetale)
LaSepale=DonneeApr[:,2]
#print(LoSepale)
LoSepale=DonneeApr[:,3]
#print(LaSepale)


###########################################################
#==0
####################################################
rows0=np.where(DonneeApr[:,4]==0)
result0=DonneeApr[rows0]
#print(result0)

LargPetale0=result0[:,0]
LongPetale0=result0[:,1]
LargSepale0=result0[:,2]
LongSepale0=result0[:,3]

#moyenne


MLargPetale0=np.mean(LargPetale0)
MLongPetale0=np.mean(LongPetale0)
MLargSepale0=np.mean(LargSepale0)
MLongSetale0=np.mean(LongSepale0)


#Ecart-type

ETLargPetale0=np.sqrt(np.var(LargPetale0,axis=0,ddof=1))
ETLongPetale0=np.sqrt(np.var(LongPetale0,axis=0,ddof=1))
ETLargSepale0=np.sqrt(np.var(LargSepale0,axis=0,ddof=1))
ETLongSetale0=np.sqrt(np.var(LongSepale0,axis=0,ddof=1))
print(" ")

print("E-T de la largeur de la petale0",ETLargPetale0)
print("E-T de la longueur de la petale0",ETLongPetale0)
print("E-T de la longueur de la sepale0",ETLargSepale0)
print("E-T de la longueur de la sepale0",ETLongSetale0)
print(" ")


###########################################################
#==1
####################################################
rows1=np.where(DonneeApr[:,4]==1)
result1=DonneeApr[rows1]


LargPetale1=result1[:,0]
LongPetale1=result1[:,1]
LargSepale1=result1[:,2]
LongSepale1=result1[:,3]

#moyenne


MLargPetale1=np.mean(LargPetale1)
MLongPetale1=np.mean(LongPetale1)
MLargSepale1=np.mean(LargSepale1)
MLongSetale1=np.mean(LongSepale1)

print("Moyenne de la largeur de la petale1",MLargPetale1)
print("Moyenne de la longueur de la petale1",MLongPetale1)
print("Moyenne de la largeur de la sepale1",MLargSepale1)
print("moyenne de la longueur de la sepale1",MLongSetale1)
print(" ")
#Ecart-type

ETLargPetale1=np.sqrt(np.var(LargPetale1,axis=0,ddof=1))
ETLongPetale1=np.sqrt(np.var(LongPetale1,axis=0,ddof=1))
ETLargSepale1=np.sqrt(np.var(LargSepale1,axis=0,ddof=1))
ETLongSetale1=np.sqrt(np.var(LongSepale1,axis=0,ddof=1))
print(" ")

print("E-T de la largeur de la petale1",ETLargPetale1)
print("E-T de la longueur de la petale1",ETLongPetale1)
print("E-T de la longueur de la sepale1",ETLargSepale1)
print("E-T de la longueur de la sepale1",ETLongSetale1)
print(" ")




###########################################################
#==2
####################################################

rows2=np.where(DonneeApr[:,4]==2)
result2=DonneeApr[rows2]


LargPetale2=result2[:,0]
LongPetale2=result2[:,1]
LargSepale2=result2[:,2]
LongSepale2=result2[:,3]

#moyenne


MLargPetale2=np.mean(LargPetale2)
MLongPetale2=np.mean(LongPetale2)
MLargSepale2=np.mean(LargSepale2)
MLongSetale2=np.mean(LongSepale2)
print(" ")

print("Moyenne de la largeur de la petale2",MLargPetale2)
print("Moyenne de la longueur de la petale2",MLongPetale2)
print("Moyenne de la largeur de la sepale2",MLargSepale2)
print("moyenne de la longueur de la sepale2",MLongSetale2)
print(" ")

#Ecart-type

ETLargPetale2=np.sqrt(np.var(LargPetale2,axis=0,ddof=1))
ETLongPetale2=np.sqrt(np.var(LongPetale2,axis=0,ddof=1))
ETLargSepale2=np.sqrt(np.var(LargSepale2,axis=0,ddof=1))
ETLongSetale2=np.sqrt(np.var(LongSepale2,axis=0,ddof=1))
print(" ")

print("E-T de la largeur de la petale2",ETLargPetale2)
print("E-T de la longueur de la petale2",ETLongPetale2)
print("E-T de la longueur de la sepale2",ETLargSepale2)
print("E-T de la longueur de la sepale2",ETLongSetale2)
print(" ")
# Out:
#
# Moyenne de la largeur de la petale0 4.961290322580646
# Moyenne de la longueur de la petale0 3.429032258064516
# Moyenne de la largeur de la sepale0 1.4645161290322577
# moyenne de la longueur de la sepale0 0.24838709677419357
#
#
# E-T de la largeur de la petale0 0.3684900897399538
# E-T de la longueur de la petale0 0.4100354036642014
# E-T de la longueur de la sepale0 0.19243767319450764
# E-T de la longueur de la sepale0 0.10605334425635522
#
# Moyenne de la largeur de la petale1 5.912121212121211
# Moyenne de la longueur de la petale1 2.784848484848485
# Moyenne de la largeur de la sepale1 4.2727272727272725
# moyenne de la longueur de la sepale1 1.3393939393939396
#
#
# E-T de la largeur de la petale1 0.5224686448472147
# E-T de la longueur de la petale1 0.3308334287458835
# E-T de la longueur de la sepale1 0.47583658386619937
# E-T de la longueur de la sepale1 0.1818986564329743
#
#
# Moyenne de la largeur de la petale2 6.455555555555555
# ...

# %%
tab=np.array([[(MLargPetale0,ETLargPetale0),(MLongPetale0,ETLongPetale0),(MLargSepale0,ETLargSepale0),(MLongSetale0,ETLongSetale0)],
             [(MLargPetale1,ETLargPetale1),(MLongPetale1,ETLongPetale1),(MLargSepale1,ETLargSepale1),(MLongSetale1,ETLongSetale1)],
             [(MLargPetale2,ETLargPetale2),(MLongPetale2,ETLongPetale2),(MLargSepale2,ETLargSepale2),(MLongSetale2,ETLongSetale2)]])

print(tab)


# on calcule la moyenne d apparition des 0
P0=len(result0)/nbDonneeApr

#print("P (0) = ",P0,"" )

# on calcule la moyenne d apparition des 1
P1=len(result1)/nbDonneeApr
#print(P1)
# on calcule la moyenne d apparition des 2
P2=len(result2)/nbDonneeApr
#print(P2)



print("\n la covariance \n")
l=5.9
w=3.0




def vrai(x,m,v):
    return sp.stats.norm.pdf(x,m,v)
# 0
print ("\nj ai un iris avec l =",l,' et w =',w,'\n')
ppetalLar0 = vrai(l,MLargPetale0,ETLargPetale0)
ppetalLon0 = vrai(w,MLongPetale0,ETLongPetale0)

print("proba 0 = ", P0 *psepalLar0*psepalLon0)

psepalLar0 = vrai(l,MLargSepale0,ETLargSepale0)
psepalLon0 = vrai(w,MLongSetale0,ETLongSetale0)
print("proba 0 = ",P0*ppetalLar0 *ppetalLon0)



#1
ppetalLar1 = cvraiov(l,MLargPetale1,ETLargPetale1)
ppetalLon1 = vrai(w,MLongPetale1,ETLongPetale1)

print("proba 1 = ",P1 *psepalLar1*psepalLon1)

psepalLar1 = vrai(l,MLargSepale1,ETLargSepale1)
psepalLon1 = vrai(w,MLongSetale1,ETLongSetale1)

print("proba 1 = ",P1*ppetalLon1*ppetalLar1)

#2
ppetalLar2 = vrai(l,MLargPetale2,ETLargPetale2)
ppetalLon2 = vrai(w,MLongPetale2,ETLongPetale2)

print("proba 2 = ",P2 *psepalLar2*psepalLon2)

psepalLar2 = vrai(l,MLargSepale2,ETLargSepale2)
psepalLon2 = vrai(w,MLongSetale2,ETLongSetale2)
print("proba 1 = ",P1 *ppetalLon1*ppetalLar1)
# Out:
# [[[4.96129032 0.36849009]
#   [3.42903226 0.4100354 ]
#   [1.46451613 0.19243767]
#   [0.2483871  0.10605334]]
#
#  [[5.91212121 0.52246864]
#   [2.78484848 0.33083343]
#   [4.27272727 0.47583658]
#   [1.33939394 0.18189866]]
#
#  [[6.45555556 0.55623451]
#   [2.92777778 0.29627315]
#   [5.41944444 0.43544358]
#   [1.98888889 0.28762851]]]
#
#  la covariance
#
#
# j ai un iris avec l = 5.9  et w = 3.0 les sepale de l =  5.1 w sepale = 1.8
#
# proba 0 =  6.010679122538797e-126
# proba 1 =  0.004041300898876266
# proba 2 =  0.16039635656443854

# %%
# on affiche les paires qui peuvent le mieux correspondre
label = iris.target
dim = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width']
irisdata = iris.data

def nuage(x1, x2, y, dim1='dim1', dim2='dim2'):
    plt.scatter(x1, x2, c=y)
    plt.title('nuage de points')
    plt.xlabel(dim1)
    plt.ylabel(dim2)
    plt.show()
    

nuage(X[:,0],X[:,2],label,dim[0],dim[2])

# %% [raw]
# Maintenant que nous avons les trois valeur pour les fleurs
# Phase de développement

# %%
#print(DonneeDev)



for i in range (3):
    trows0=np.where(DonneeDev[:,4]==i)
    tresult0=DonneeDev[trows0]





moyennelarP0=moyenne(tresult0,0)
print(moyennelarP0)
variancelarP0=variance(tresult0,0)
print(variancelarP0)
# Out:
# [[4.4 3.  1.3 0.2 0. ]
#  [5.4 3.9 1.7 0.4 0. ]
#  [5.1 3.5 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.2 0. ]
#  [5.2 3.4 1.4 0.2 0. ]
#  [5.  3.2 1.2 0.2 0. ]
#  [5.1 3.3 1.7 0.5 0. ]
#  [5.4 3.4 1.5 0.4 0. ]
#  [5.2 4.1 1.5 0.1 0. ]
#  [5.8 4.  1.2 0.2 0. ]
#  [5.1 3.8 1.5 0.3 0. ]
#  [4.7 3.2 1.6 0.2 0. ]
#  [5.  3.3 1.4 0.2 0. ]]
# 5.1000000000000005
# 0.34156502553198653
